# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import pandas_datareader as web
import datetime as dt
import pandas as pd

# %%
def crypto(x):
    start = dt.datetime(2008,1,1)
    end = dt.datetime.now()

    x = web.DataReader(str(x)+'-USD', 'yahoo', start, end)
    return x

# %%
df = crypto('BTC')
df.tail()
# Out:
#                     High           Low          Open         Close  \
# Date
# 2022-01-28  37952.878906  36211.109375  37128.445312  37784.332031
# 2022-01-29  38576.261719  37406.472656  37780.714844  38138.179688
# 2022-01-30  38266.339844  37437.710938  38151.917969  37917.601562
# 2022-01-31  38647.261719  36733.574219  37920.281250  38483.125000
# 2022-02-02  38777.269531  38706.382812  38758.101562  38775.781250
#
#                   Volume     Adj Close
# Date
# 2022-01-28  2.223883e+10  37784.332031
# 2022-01-29  1.719418e+10  38138.179688
# 2022-01-30  1.464355e+10  37917.601562
# 2022-01-31  2.073473e+10  38483.125000
# 2022-02-02  2.020189e+10  38775.781250

# %%
df.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
df.index = pd.to_datetime(df.index, format ='%Y-%m-%d')

# %%
df.tail()
# Out:
#                     High           Low          Open         Close  \
# Date
# 2022-01-28  37952.878906  36211.109375  37128.445312  37784.332031
# 2022-01-29  38576.261719  37406.472656  37780.714844  38138.179688
# 2022-01-30  38266.339844  37437.710938  38151.917969  37917.601562
# 2022-01-31  38647.261719  36733.574219  37920.281250  38483.125000
# 2022-02-02  38777.269531  38706.382812  38758.101562  38775.781250
#
#                   Volume     Adj Close
# Date
# 2022-01-28  2.223883e+10  37784.332031
# 2022-01-29  1.719418e+10  38138.179688
# 2022-01-30  1.464355e+10  37917.601562
# 2022-01-31  2.073473e+10  38483.125000
# 2022-02-02  2.020189e+10  38775.781250

# %% [markdown]
# # Criando campos de MA5d e MA21d

# %%
df['ma5d'] = df['Close'].rolling(5).mean()
df['ma21d'] = df['Close'].rolling(21).mean()

# %%
df.tail(7)
# Out:
#                     High           Low          Open         Close  \
# Date
# 2022-01-26  38825.410156  36374.906250  36950.515625  36852.121094
# 2022-01-27  37148.324219  35629.281250  36841.878906  37138.234375
# 2022-01-28  37952.878906  36211.109375  37128.445312  37784.332031
# 2022-01-29  38576.261719  37406.472656  37780.714844  38138.179688
# 2022-01-30  38266.339844  37437.710938  38151.917969  37917.601562
# 2022-01-31  38647.261719  36733.574219  37920.281250  38483.125000
# 2022-02-02  38777.269531  38706.382812  38758.101562  38775.781250
#
#                   Volume     Adj Close          ma5d         ma21d
# Date
# 2022-01-26  3.132460e+10  36852.121094  36353.501563  40672.804501
# 2022-01-27  2.504143e+10  37138.234375  36775.098437  40386.009487
# 2022-01-28  2.223883e+10  37784.332031  37076.603906  40206.315662
# 2022-01-29  1.719418e+10  38138.179688  37373.374219  40035.088914
# 2022-01-30  1.464355e+10  37917.601562  37566.093750  39844.898438
# 2022-01-31  2.073473e+10  38483.125000  37892.294531  39685.939546
# 2022-02-02  2.020189e+10  38775.781250  38219.803906  39497.364583

# %%
df['Close'] = df['Close'].shift(-1)

df
# Out:
#                     High           Low          Open         Close  \
# Date
# 2014-09-17    468.174011    452.421997    465.864014    424.440002
# 2014-09-18    456.859985    413.104004    456.859985    394.795990
# 2014-09-19    427.834991    384.532013    424.102997    408.903992
# 2014-09-20    423.295990    389.882996    394.673004    398.821014
# 2014-09-21    412.425995    393.181000    408.084991    402.152008
# ...                  ...           ...           ...           ...
# 2022-01-28  37952.878906  36211.109375  37128.445312  38138.179688
# 2022-01-29  38576.261719  37406.472656  37780.714844  37917.601562
# 2022-01-30  38266.339844  37437.710938  38151.917969  38483.125000
# 2022-01-31  38647.261719  36733.574219  37920.281250  38775.781250
# 2022-02-02  38777.269531  38706.382812  38758.101562           NaN
#
#                   Volume     Adj Close          ma5d         ma21d
# Date
# 2014-09-17  2.105680e+07    457.334015           NaN           NaN
# 2014-09-18  3.448320e+07    424.440002           NaN           NaN
# 2014-09-19  3.791970e+07    394.795990           NaN           NaN
# 2014-09-20  3.686360e+07    408.903992           NaN           NaN
# 2014-09-21  2.658010e+07    398.821014    416.859003           NaN
# ...                  ...           ...           ...           ...
# 2022-01-28  2.223883e+10  37784.332031  37076.603906  40206.315662
# 2022-01-29  1.719418e+10  38138.179688  37373.374219  40035.088914
# 2022-01-30  1.464355e+10  37917.601562  37566.093750  39844.898438
# 2022-01-31  2.073473e+10  38483.125000  37892.294531  39685.939546
# 2022-02-02  2.020189e+10  38775.781250  38219.803906  39497.364583
#
# [2695 rows x 8 columns]

# %%
df.dropna(inplace=True)

df
# Out:
#                     High           Low          Open         Close  \
# Date
# 2014-10-07    339.247009    320.481995    330.584015    352.940002
# 2014-10-08    354.364014    327.187988    336.115997    365.026001
# 2014-10-09    382.726013    347.687012    352.747986    361.562012
# 2014-10-10    375.066986    352.963013    364.687012    362.299011
# 2014-10-11    367.191010    355.950989    361.362000    378.549011
# ...                  ...           ...           ...           ...
# 2022-01-27  37148.324219  35629.281250  36841.878906  37784.332031
# 2022-01-28  37952.878906  36211.109375  37128.445312  38138.179688
# 2022-01-29  38576.261719  37406.472656  37780.714844  37917.601562
# 2022-01-30  38266.339844  37437.710938  38151.917969  38483.125000
# 2022-01-31  38647.261719  36733.574219  37920.281250  38775.781250
#
#                   Volume     Adj Close          ma5d         ma21d
# Date
# 2014-10-07  4.919990e+07    336.187012    335.030804    387.352142
# 2014-10-08  5.473630e+07    352.940002    333.716406    382.380999
# 2014-10-09  8.364110e+07    365.026001    340.948407    379.551761
# 2014-10-10  4.366570e+07    361.562012    349.158807    377.969190
# 2014-10-11  1.334520e+07    362.299011    355.602808    375.749906
# ...                  ...           ...           ...           ...
# 2022-01-27  2.504143e+10  37138.234375  36775.098437  40386.009487
# 2022-01-28  2.223883e+10  37784.332031  37076.603906  40206.315662
# 2022-01-29  1.719418e+10  38138.179688  37373.374219  40035.088914
# 2022-01-30  1.464355e+10  37917.601562  37566.093750  39844.898438
# 2022-01-31  2.073473e+10  38483.125000  37892.294531  39685.939546
#
# [2674 rows x 8 columns]

# %% [markdown]
# # Verificando Quantidade de Linhas

# %%
line_count = len(df)
#print(line_count)
line_count_training = round(line_count *0.7)
line_count_test = line_count - 60

line_count_validator = line_count_training - line_count_test

info = (
    f"linhas treino= 0:{line_count_training}"
    f" linhas teste= {line_count_training}:{line_count_training + line_count_test -1}"
    f" linhas validação= {line_count_validator}"
)

# %% [markdown]
# # Colocando o Indice(ano-mes-dia) como Coluna de dia

# %%
#df['Day'] = df.index
df = df.reset_index()

# %%
df.tail()
# Out:
#            Date          High           Low          Open         Close  \
# 2669 2022-01-27  37148.324219  35629.281250  36841.878906  37784.332031
# 2670 2022-01-28  37952.878906  36211.109375  37128.445312  38138.179688
# 2671 2022-01-29  38576.261719  37406.472656  37780.714844  37917.601562
# 2672 2022-01-30  38266.339844  37437.710938  38151.917969  38483.125000
# 2673 2022-01-31  38647.261719  36733.574219  37920.281250  38775.781250
#
#             Volume     Adj Close          ma5d         ma21d
# 2669  2.504143e+10  37138.234375  36775.098437  40386.009487
# 2670  2.223883e+10  37784.332031  37076.603906  40206.315662
# 2671  1.719418e+10  38138.179688  37373.374219  40035.088914
# 2672  1.464355e+10  37917.601562  37566.093750  39844.898438
# 2673  2.073473e+10  38483.125000  37892.294531  39685.939546

# %%
features = df.drop(['Date', 'Close'], 1)
labels = df['Close']
# Out:
# C:\Users\Hayek\AppData\Local\Temp\ipykernel_6596\196778337.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   features = df.drop(['Date', 'Close'], 1)

# %%
features_list = ['Open', 'Volume', 'ma5d', 'ma21d' ]#'Adj Close', 

k_best_features = SelectKBest(k='all')
k_best_features.fit_transform(features, labels)
k_best_features_scores = k_best_features.scores_
raw_pairs = zip(features_list[1:], k_best_features_scores)
ordered_pairs = list(reversed(sorted(raw_pairs, key=lambda x: x[1])))

k_best_features_final = dict(ordered_pairs[:15])
best_features = k_best_features_final.keys()
print('')
print('Melhores features: ')
print(k_best_features_final)
# Out:
# Melhores features:
# {'Volume': 6953.496999191339, 'ma5d': 5940.248371162556, 'ma21d': 4481.862421142788}

# %%
features = df.drop(['Date', 'High', 'Low', 'Open', 'Close', 'Adj Close', ], 1) #'Adj Close', adicionado
# Out:
# C:\Users\Hayek\AppData\Local\Temp\ipykernel_6596\2919272141.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   features = df.drop(['Date', 'High', 'Low', 'Open', 'Close', 'Adj Close', ], 1) #'Adj Close', adicionado

# %%
volume = 20166322176
adj_close = 38742.082031
ma5d = 38213.064063
ma21d = 39495.759859
date_today = '2022-02-01'
teste_valores = {'Volume': volume,  'ma5d': ma5d, 'ma21d': ma21d} #'Adj Close': adj_close,
features = features.append(teste_valores, ignore_index = True)
features
# Out:
# C:\Users\Hayek\AppData\Local\Temp\ipykernel_6596\224096385.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features = features.append(teste_valores, ignore_index = True)
#             Volume          ma5d         ma21d
# 0     4.919990e+07    335.030804    387.352142
# 1     5.473630e+07    333.716406    382.380999
# 2     8.364110e+07    340.948407    379.551761
# 3     4.366570e+07    349.158807    377.969190
# 4     1.334520e+07    355.602808    375.749906
# ...            ...           ...           ...
# 2670  2.223883e+10  37076.603906  40206.315662
# 2671  1.719418e+10  37373.374219  40035.088914
# 2672  1.464355e+10  37566.093750  39844.898438
# 2673  2.073473e+10  37892.294531  39685.939546
# 2674  2.016632e+10  38213.064063  39495.759859
#
# [2675 rows x 3 columns]

# %%
scaler = MinMaxScaler().fit(features)
features_scale = (scaler.transform(features))

print('Features: ', features_scale.shape)
print(features_scale)
# Out:
# Features:  (2675, 3)
# [[1.23333371e-04 2.04347148e-03 2.55462714e-03]
#  [1.39108297e-04 2.02341254e-03 2.47545611e-03]
#  [2.21467076e-04 2.13377956e-03 2.43039732e-03]
#  ...
#  [4.17071727e-02 5.70223916e-01 6.30960277e-01]
#  [5.90628453e-02 5.75202041e-01 6.28428679e-01]
#  [5.74432732e-02 5.80097281e-01 6.25399854e-01]]

# %%
X_train = features_scale[:line_count_training]
X_test = features_scale[line_count_training:line_count_test]

y_train = labels[:line_count_training]
y_test = labels[line_count_training:line_count_test]

print(len(X_train), len(y_train))

print( len(X_test), len(y_test))
# Out:
# 1872 1872
# 742 742

# %%
#df = df.append({'Volume': volume, 'Adj Close': adj_close, 'ma5d': ma5d, 'ma21d': ma21d, 'Date': date_today}, ignore_index = True)
df
# Out:
#            Date          High           Low          Open         Close  \
# 0    2014-10-07    339.247009    320.481995    330.584015    352.940002
# 1    2014-10-08    354.364014    327.187988    336.115997    365.026001
# 2    2014-10-09    382.726013    347.687012    352.747986    361.562012
# 3    2014-10-10    375.066986    352.963013    364.687012    362.299011
# 4    2014-10-11    367.191010    355.950989    361.362000    378.549011
# ...         ...           ...           ...           ...           ...
# 2669 2022-01-27  37148.324219  35629.281250  36841.878906  37784.332031
# 2670 2022-01-28  37952.878906  36211.109375  37128.445312  38138.179688
# 2671 2022-01-29  38576.261719  37406.472656  37780.714844  37917.601562
# 2672 2022-01-30  38266.339844  37437.710938  38151.917969  38483.125000
# 2673 2022-01-31  38647.261719  36733.574219  37920.281250  38775.781250
#
#             Volume     Adj Close          ma5d         ma21d
# 0     4.919990e+07    336.187012    335.030804    387.352142
# 1     5.473630e+07    352.940002    333.716406    382.380999
# 2     8.364110e+07    365.026001    340.948407    379.551761
# 3     4.366570e+07    361.562012    349.158807    377.969190
# 4     1.334520e+07    362.299011    355.602808    375.749906
# ...            ...           ...           ...           ...
# 2669  2.504143e+10  37138.234375  36775.098437  40386.009487
# 2670  2.223883e+10  37784.332031  37076.603906  40206.315662
# 2671  1.719418e+10  38138.179688  37373.374219  40035.088914
# 2672  1.464355e+10  37917.601562  37566.093750  39844.898438
# 2673  2.073473e+10  38483.125000  37892.294531  39685.939546
#
# [2674 rows x 9 columns]

# %%
lr = linear_model.LinearRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
cd = r2_score(y_test, pred)

f'Coeficiente de determinação: {cd*100:.2f}'
# Out:
# 'Coeficiente de determinação: 99.08'

# %%
#rn = MLPRegressor(max_iter=2000)
#
#rn.fit(X_train, y_train)
#pred = rn.predict(X_test)
#
#cd = rn.score(X_test, y_test)
#f'Coeficiente de determinação: {cd*100:.2f}'
# Out:
# C:\ProgramData\Anaconda3\envs\webApp\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 'Coeficiente de determinação: 45.33'

# %%
##REDE NEURAL COM AJUSTE DE HYPER PARAMETERS
#
#rn = MLPRegressor()
#parameter_space = {
#    'hidden_layer_sizes': [(i,) for i in list(range(1,21))],
#    'activation': ['tanh', 'relu'],
#    'solver': ['sgd', 'adam', 'lbfgs'],
#    'alpha': [0.0001, 0.05],
#    'learning_rate': ['constant', 'adaptive'],
#    }
#
#search = GridSearchCV(rn, parameter_space, n_jobs=-1, cv=5)
#
#search.fit(X_train, y_train)
#clf = search.best_estimator_
#pred = search.predict(X_test)
#
#cd = search.score(X_test, y_test)
#
#f'Coeficiente de determinação: {cd*100:.2f}'
# Out:
# 'Coeficiente de determinação: 99.08'

# %%
previsao = features_scale[line_count_test:line_count]

date_full = df['Date']
date = date_full[line_count_test:line_count]

res_full = df['Close']
res = res_full[line_count_test:line_count]

pred = lr.predict(previsao)

df_final = pd.DataFrame({'date':date, 'real':res, 'previsao':pred})
df_final['real'] = df_final['real'].shift(+1)

df_final.set_index('date', inplace=True)

print(df_final)
# Out:
#                     real      previsao
# date
# 2021-12-03           NaN  55616.493879
# 2021-12-04  49200.703125  53853.469982
# 2021-12-05  49368.847656  52110.769999
# 2021-12-06  50582.625000  50684.307445
# 2021-12-07  50700.085938  49409.823424
# 2021-12-08  50504.796875  48750.967480
# 2021-12-09  47672.121094  48476.550238
# 2021-12-10  47243.304688  48078.346991
# 2021-12-11  49362.507812  47854.372369
# 2021-12-12  50098.335938  47765.635707
# 2021-12-13  46737.480469  47019.743181
# 2021-12-14  46612.632812  46872.602721
# 2021-12-15  48896.722656  47319.422972
# 2021-12-16  47665.425781  46961.350558
# 2021-12-17  46202.144531  46147.777293
# 2021-12-18  46848.777344  46204.404429
# 2021-12-19  46707.015625  46303.996318
# 2021-12-20  46880.277344  45951.609142
# 2021-12-21  48936.613281  46289.246145
# 2021-12-22  48628.511719  46902.848699
# 2021-12-23  50784.539062  47870.361779
# 2021-12-24  50822.195312  48821.549067
# 2021-12-25  50429.859375  49604.560968
# 2021-12-26  50809.515625  50033.241194
# 2021-12-27  50640.417969  50511.214376
# 2021-12-28  47588.855469  49841.553725
# 2021-12-29  46444.710938  48850.215508
# 2021-12-30  47178.125000  48090.266564
# 2021-12-31  46306.445312  47108.140758
# 2022-01-01  47686.812500  46384.761285
# 2022-01-02  47345.218750  46365.544861
# 2022-01-03  46458.117188  46394.207386
# 2022-01-04  45897.574219  46148.109152
# 2022-01-05  43569.003906  45533.793189
# 2022-01-06  43160.929688  44496.856741
# 2022-01-07  41557.902344  43447.762301
# 2022-01-08  41733.941406  42143.785431
# 2022-01-09  41911.601562  41232.795726
# 2022-01-10  41821.261719  40919.371070
# 2022-01-11  42735.855469  40843.477582
# 2022-01-12  43949.101562  41463.105197
# 2022-01-13  42591.570312  41789.229299
# 2022-01-14  43099.699219  42012.692223
# 2022-01-15  43177.398438  42357.576151
# 2022-01-16  43113.878906  42502.436071
# 2022-01-17  42250.550781  42194.215131
# 2022-01-18  42375.632812  42188.476844
# 2022-01-19  41744.328125  41916.246160
# 2022-01-20  40680.417969  41379.806066
# 2022-01-21  36457.316406  40027.910685
# 2022-01-22  35030.250000  38449.660256
# 2022-01-23  36276.804688  37069.627941
# 2022-01-24  36654.328125  36046.909028
# 2022-01-25  36954.003906  35188.439798
# 2022-01-26  36852.121094  35354.052871
# 2022-01-27  37138.234375  35857.475096
# 2022-01-28  37784.332031  36221.065369
# 2022-01-29  38138.179688  36567.573813
# 2022-01-30  37917.601562  36808.841016
# 2022-01-31  38483.125000  37238.101391

# %%
valor_novo = features.tail(1)
valor_novo
# Out:
#             Volume          ma5d         ma21d
# 2674  2.016632e+10  38213.064063  39495.759859

# %%
previsao=scaler.transform(valor_novo)

pred = lr.predict(previsao)

pred
# Out:
# array([37635.78823717])

# %%
df_final.to_excel("output.xlsx")

# %%
plt.figure(figsize = (32, 16))
plt.title('Preço do Bitcoin')
plt.plot(df_final['real'], label = 'real', color='blue', marker = 'o')
plt.plot(df_final['previsao'], label = 'previsao', color='red', marker = 'o')
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento')
leg = plt.legend()
